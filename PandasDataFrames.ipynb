# %% [markdown]
# # Pandas DataFrame operations
#
# This is a reference notebook for useful operations on python pandas package's dataframe data type.

# %%
import pandas as pd

# %% [markdown]
# ## Initialization

# %%
new_df = pd.DataFrame()

# %% [markdown]
# #### Read Excel, way 1
# This is a little faster, than way2

# %%
excel_obj = pd.ExcelFile("/Users/korolo/data/cssp/fungal_synonyms/Amy_ICTF/pathogenic_fungi_ICTF.xlsx")
excel_df = excel_obj.parse('original_data')  # sheet name

# %% [markdown]
# #### Read Excel, way 2:
# A little slower than way1

# %%
df = pd.read_excel('/Users/korolo/data/cssp/fungal_synonyms/Amy_ICTF/pathogenic_fungi_ICTF.xlsx', sheet_name='original_data')

# %% [markdown]
# #### Read json from URL, way 1
# This is brittle, since it's using local solr url as an example

# %%
query_url = 'http://localhost:8983/solr/CFIA_all/select?fl=id&q=title:grain'

# %%
df2 = pd.read_json(query_url)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/miniconda3/envs/ipython/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~/miniconda3/envs/ipython/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-16-a8eaf28fff1f> in <module>()
# ----> 1 df2 = pd.read_json(query_url)
#       2 df2.head()
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     350     compression = _infer_compression(path_or_buf, compression)
#     351     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 352         path_or_buf, encoding=encoding, compression=compression,
#     353     )
#     354
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     188
#     189     if _is_url(filepath_or_buffer):
# --> 190         req = _urlopen(filepath_or_buffer)
#     191         content_encoding = req.headers.get('Content-Encoding', None)
#     192         if content_encoding == 'gzip':
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 61] Connection refused>

# %% [markdown]
# #### Read json from url, way 1

# %%
import requests

query_url = 'http://localhost:8983/solr/CFIA_all/select?fl=id&q=title:grain'
r = requests.get(query_url)
query_response_df = pd.DataFrame(r.json()['response']['docs'])
query_response_df.head()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10dedcac8>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=8983): Max retries exceeded with url: /solr/CFIA_all/select?fl=id&q=title:grain (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10dedcac8>: Failed to establish a new connection: [Errno 61] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-17-30216b5c8b8b> in <module>()
#       2
#       3 query_url = 'http://localhost:8983/solr/CFIA_all/select?fl=id&q=title:grain'
# ----> 4 r = requests.get(query_url)
#       5 query_response_df = pd.DataFrame(r.json()['response']['docs'])
#       6 query_response_df.head()
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=8983): Max retries exceeded with url: /solr/CFIA_all/select?fl=id&q=title:grain (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10dedcac8>: Failed to establish a new connection: [Errno 61] Connection refused',))

# %% [markdown]
# #### Read json from url, way 2 (no requests)
# Note that this method does not use request or any other library, but pandas. The downside is that it reads into dataframe exactly what the url returned, so headers and everything. If you need to pre-process the json before, then the requests way above is a better option.

# %%
df2 = pd.read_json(query_url)
df2
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/miniconda3/envs/ipython/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/miniconda3/envs/ipython/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~/miniconda3/envs/ipython/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-18-e5784c631c3f> in <module>()
# ----> 1 df2 = pd.read_json(query_url)
#       2 df2
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     350     compression = _infer_compression(path_or_buf, compression)
#     351     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 352         path_or_buf, encoding=encoding, compression=compression,
#     353     )
#     354
#
# ~/miniconda3/envs/ipython/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     188
#     189     if _is_url(filepath_or_buffer):
# --> 190         req = _urlopen(filepath_or_buffer)
#     191         content_encoding = req.headers.get('Content-Encoding', None)
#     192         if content_encoding == 'gzip':
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~/miniconda3/envs/ipython/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 61] Connection refused>

# %% [markdown]
# ## Exploring /viewing

# %%
pd.set_option('display.max_rows', 150)
excel_df
# Out:
#                                                  GENERA  \
# 0                                         Kingdom Fungi
# 1                                       Chytridiomycota
# 2                                       Blastocladiales
# 3                                      Physodermataceae
# 4                                            Physoderma
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                         Chytridiales
# 11                                       Synchytriaceae
# 12                                          Synchytrium
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                    Spizellomycetales
# 19                                          Olpidiaceae
# 20                                             Olpidium
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                           Zygomycota
# 26                                            Mucorales
# 27                                      Choanephoraceae
# 28                                          Choanephora
# 29                                                  NaN
# 30                                                  NaN
# 31                                      Gilbertellaceae
# 32                                          Gilbertella
# 33                                                  NaN
# 34                                           Mucoraceae
# 35                                                Mucor
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                             Rhizopus
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                                                  NaN
# 49                                                  NaN
# 50                                           Ascomycota
# 51                                      Saccharomycetes
# 52                                    Saccharomycetales
# 53                                        Dipodascaceae
# 54                                           Geotrichum
# 55                                    Syn. Galactomyces
# 56                                                  NaN
# 57                                                  NaN
# 58                                                  NaN
# 59                                                  NaN
# 60                                                  NaN
# 61                                      Eremotheciaceae
# 62                                         Eremothecium
# 63                                                  NaN
# 64                                         Eremothecium
# 65                                                  NaN
# 66                                                  NaN
# 67                                                  NaN
# 68                                      Taphrinomycetes
# 69                                          Taphrinales
# 70                                         Taphrinaceae
# 71                                             Taphrina
# 72                                                  NaN
# 73                                                  NaN
# 74                                                  NaN
# ...                                                 ...
# 2544                                                NaN
# 2545                                                NaN
# 2546                                                NaN
# 2547                                        Peronospora
# 2548                                                NaN
# 2549                                                NaN
# 2550                                                NaN
# 2551                                                NaN
# 2552                                                NaN
# 2553                                                NaN
# 2554                                                NaN
# 2555                                                NaN
# 2556                                                NaN
# 2557                                                NaN
# 2558                                                NaN
# 2559                                                NaN
# 2560                                                NaN
# 2561                                                NaN
# 2562                                                NaN
# 2563                                                NaN
# 2564                                         Plasmopara
# 2565                                                NaN
# 2566                                                NaN
# 2567                                                NaN
# 2568                                                NaN
# 2569                                  Pseudoperonospora
# 2570                                                NaN
# 2571                                      Sclerophthora
# 2572                                     Sclerophthora*
# 2573  * will be tranferred to a new genus, not close...
# 2574                                 Peronophytophthora
# 2575                                       Phytophthora
# 2576                                                NaN
# 2577                                                NaN
# 2578                                                NaN
# 2579                                                NaN
# 2580                                                NaN
# 2581                                                NaN
# 2582                                                NaN
# 2583                                                NaN
# 2584                                                NaN
# 2585                                                NaN
# 2586                                                NaN
# 2587                                                NaN
# 2588                                                NaN
# 2589                                                NaN
# 2590                                                NaN
# 2591                                                NaN
# 2592                                       Phytopythium
# 2593                                         Pythiaceae
# 2594                                                NaN
# 2595                                                NaN
# 2596                                                NaN
# 2597                                                NaN
# 2598                                            Pythium
# 2599                                                NaN
# 2600                                                NaN
# 2601                                     Saprolegniales
# 2602                                     Verrucalvaceae
# 2603                                        Aphanomyces
# 2604                                         Pachymetra
# 2605                                   Kingdom Rhizaria
# 2606                              Plasmodiophoromycetes
# 2607                                  Plasmodiophorales
# 2608                                 Plasmodiophoraceae
# 2609                                     Plasmodiophora
# 2610                                           Polymyxa
# 2611                                        Spongospora
# 2612                                                NaN
# 2613                                                NaN
# 2614                                                NaN
# 2615                                                NaN
# 2616                                                NaN
# 2617                                                NaN
# 2618   I’ve just reduced all to the order level, rat...
#
#                              SPECIES NAME AND SYNONYMYS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Physoderma alfalfae (Pat. & Lagerh.) Karling 1950
# 5         ≡ Cladochytrium alfalfae Pat. & Lagerh. 1895
# 6     ≡ Urophlyctis alfalfae (Pat. & Lagerh.) Magnus...
# 7                Physoderma maydis (Miyabe) Miyabe 1909
# 8                   ≡ Cladochytrium maydis Miyabe 1903
# 9              = Physoderma zeae-maydis F.J. Shaw 1912
# 10                                                  NaN
# 11                                                  NaN
# 12    Synchytrium endobioticum (Schilb.) Percival 19...
# 13          ≡ Chrysophlyctis endobioticum Schilb. 1896
# 14                    = Synchytrium solani Massee 1910
# 15             Synchytrium dolichi (Cooke) Gaeum. 1927
# 16                       ≡ Aecidium dolichi Cooke 1882
# 17             ≡ Woroninella dolichi (Cooke) Syd. 1914
# 18                                                  NaN
# 19                                                  NaN
# 20         Olpidium brassicae (Woronin) P.A. Dang. 1886
# 21                 ≡ Chytridium brassicae Woronin 1878
# 22                     = Olpidium borzii De Wild. 1893
# 23                = Asterocystis radicis De Wild. 1893
# 24        ≡ Olpidiaster radicis (De Wild.) Pascher 1917
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 
# 2598       damping-off of various crops and ornamentals
# 2599                                                NaN
# 2600  seed rots, damping-off, seedling blights, wate...
# 2601                                                NaN
# 2602                                                NaN
# 2603                    root rots of alflafa, beet, pea
# 2604                          root disease of sugarcane
# 2605                                                NaN
# 2606                                                NaN
# 2607                                                NaN
# 2608                                                NaN
# 2609                              clubroot of crucifers
# 2610     root diseases of grasses, beets, virus vectors
# 2611                             powdery scab of potato
# 2612                                                NaN
# 2613                                                NaN
# 2614                                                NaN
# 2615                                                NaN
# 2616                                                NaN
# 2617                                                NaN
# 2618                                                NaN
#
#                                              REFERENCES
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                                                  NaN
# 49                                                  NaN
# 50                                                  NaN
# 51                                                  NaN
# 52                                                  NaN
# 53                                                  NaN
# 54                                                  NaN
# 55                                                  NaN
# 56                                                  NaN
# 57                                                  NaN
# 58                                                  NaN
# 59                                                  NaN
# 60                                                  NaN
# 61                                                  NaN
# 62                                                  NaN
# 63                                                  NaN
# 64                                                  NaN
# 65                                                  NaN
# 66                                                  NaN
# 67                                                  NaN
# 68                                                  NaN
# 69                                                  NaN
# 70                                                  NaN
# 71                                                  NaN
# 72                                                  NaN
# 73                                                  NaN
# 74                                                  NaN
# ...                                                 ...
# 2544                                                NaN
# 2545                                                NaN
# 2546                                                NaN
# 2547                                                NaN
# 2548                                                NaN
# 2549                                                NaN
# 2550                                                NaN
# 2551                                                NaN
# 2552                                                NaN
# 2553                                                NaN
# 2554                                                NaN
# 2555                                                NaN
# 2556                                                NaN
# 2557                                                NaN
# 2558                                                NaN
# 2559                                                NaN
# 2560                                                NaN
# 2561                                                NaN
# 2562                                                NaN
# 2563                                                NaN
# 2564                                                NaN
# 2565                                                NaN
# 2566                                                NaN
# 2567                                                NaN
# 2568                                                NaN
# 2569                                                NaN
# 2570                                                NaN
# 2571                                                NaN
# 2572                                                NaN
# 2573                                                NaN
# 2574                                                NaN
# 2575                                                NaN
# 2576                                                NaN
# 2577                                                NaN
# 2578                                                NaN
# 2579                                                NaN
# 2580                                                NaN
# 2581                                                NaN
# 2582                                                NaN
# 2583  Kroon, L.P.N.M., Bakker, F.T., van den Bosch, ...
# 2584                                                NaN
# 2585                                                NaN
# 2586                                                NaN
# 2587                                                NaN
# 2588                                                NaN
# 2589                                                NaN
# 2590                                                NaN
# 2591                                                NaN
# 2592                                                NaN
# 2593  Uzuhashi, S., Tojo, M., and Kakishima, M. 2010...
# 2594                                                NaN
# 2595                                                NaN
# 2596                                                NaN
# 2597                                                NaN
# 2598                                                NaN
# 2599                                                NaN
# 2600                                                NaN
# 2601                                                NaN
# 2602                                                NaN
# 2603                                                NaN
# 2604                                                NaN
# 2605                                                NaN
# 2606                                                NaN
# 2607                                                NaN
# 2608                                                NaN
# 2609                                                NaN
# 2610                                                NaN
# 2611                                                NaN
# 2612                                                NaN
# 2613                                                NaN
# 2614                                                NaN
# 2615                                                NaN
# 2616                                                NaN
# 2617                                                NaN
# 2618                                                NaN
#
# [2619 rows x 4 columns]

# %%
excel_df.columns
# Out:
# Index(['GENERA', 'SPECIES NAME AND SYNONYMYS', 'DISEASE', 'REFERENCES'], dtype='object')

# %%
excel_df.dtypes
# Out:
# GENERA                        object
# SPECIES NAME AND SYNONYMYS    object
# DISEASE                       object
# REFERENCES                    object
# dtype: object

# %%
excel_df.shape
# Out:
# (2619, 4)

# %%
excel_df.describe()
# Out:
#               GENERA SPECIES NAME AND SYNONYMYS    DISEASE  \
# count            577                       2313        469
# unique           568                       2302        458
# top     Eremothecium                             heart rot
# freq               2                          3          3
#
#                                                REFERENCES
# count                                                  39
# unique                                                 31
# top     De Beer, Z.W., Duong, T.A., Barnes, I., Wingfi...
# freq                                                    5

# %%
excel_df.head()   #excel_df.head(10)
# Out:
#              GENERA                         SPECIES NAME AND SYNONYMYS  \
# 0     Kingdom Fungi                                                NaN
# 1   Chytridiomycota                                                NaN
# 2   Blastocladiales                                                NaN
# 3  Physodermataceae                                                NaN
# 4        Physoderma  Physoderma alfalfae (Pat. & Lagerh.) Karling 1950
#
#                  DISEASE REFERENCES
# 0                    NaN        NaN
# 1                    NaN        NaN
# 2                    NaN        NaN
# 3                    NaN        NaN
# 4  crown wart of alfalfa        NaN

# %%
excel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2619 entries, 0 to 2618
# Data columns (total 4 columns):
# GENERA                        577 non-null object
# SPECIES NAME AND SYNONYMYS    2313 non-null object
# DISEASE                       469 non-null object
# REFERENCES                    39 non-null object
# dtypes: object(4)
# memory usage: 81.9+ KB

# %%
#### Slicing and dicing

# %%
excel_df[:3] # first rows
# Out:
#             GENERA SPECIES NAME AND SYNONYMYS DISEASE REFERENCES
# 0    Kingdom Fungi                        NaN     NaN        NaN
# 1  Chytridiomycota                        NaN     NaN        NaN
# 2  Blastocladiales                        NaN     NaN        NaN

# %%
excel_df[-4:] # last rows
# Out:
#                                                  GENERA  \
# 2615                                                NaN
# 2616                                                NaN
# 2617                                                NaN
# 2618   I’ve just reduced all to the order level, rat...
#
#                              SPECIES NAME AND SYNONYMYS DISEASE REFERENCES
# 2615  ≡ Sorosporium scabies (Berk.) A.A. Fisch. Wald...     NaN        NaN
# 2616                  = Spongospora solani Brunch. 1887     NaN        NaN
# 2617               = Protomyces tuber-solani Mart. 1842     NaN        NaN
# 2618                                                NaN     NaN        NaN

# %%
excel_df[3:5]  #from to
# Out:
#              GENERA                         SPECIES NAME AND SYNONYMYS  \
# 3  Physodermataceae                                                NaN
# 4        Physoderma  Physoderma alfalfae (Pat. & Lagerh.) Karling 1950
#
#                  DISEASE REFERENCES
# 3                    NaN        NaN
# 4  crown wart of alfalfa        NaN

# %% [markdown]
# ## Add data to df

# %%
df = pd.DataFrame()
data = pd.DataFrame({"A": range(3)})
df.append(data)
# Out:
#    A
# 0  0
# 1  1
# 2  2

# %%
df = pd.DataFrame()
df = df.append({'name': 'Zed', 'age': 9, 'height': 2}, ignore_index=True)
df
# Out:
#    age  height name
# 0  9.0     2.0  Zed

# %% [markdown]
# #### Add column

# %%
#df['new_col'] = df['old_col']**2

# %% [markdown]
# #### Delete column

# %%
# del df['col_to_delete']

# %% [markdown]
# #### Add row

# %%
#df.loc[3] = [1,2,3,4]  # Adds a row of ints 1,2,3,4 as a 4th row in the df. df should contain 4 columns

# %% [markdown]
# #### Delete row

# %%
# df.drop(df.index[[2]])  # drops 3rd row

# %% [markdown]
# #### Group by

# %%
#pl.groupby('some_val').mean()

# %% [markdown]
# ## Working with
#
# Note that adding one row at a time to df is computationally expensive, so better to use other datastructures to collect data and add it all in one go.

# %%
excel_df[:5]
# Out:
#              GENERA                         SPECIES NAME AND SYNONYMYS  \
# 0     Kingdom Fungi                                                NaN
# 1   Chytridiomycota                                                NaN
# 2   Blastocladiales                                                NaN
# 3  Physodermataceae                                                NaN
# 4        Physoderma  Physoderma alfalfae (Pat. & Lagerh.) Karling 1950
#
#                  DISEASE REFERENCES
# 0                    NaN        NaN
# 1                    NaN        NaN
# 2                    NaN        NaN
# 3                    NaN        NaN
# 4  crown wart of alfalfa        NaN

# %% [markdown]
# ### Create a new data frame with a subset of two columns from the original

# %%
species_disease_df = excel_df[['SPECIES NAME AND SYNONYMYS','DISEASE']]
species_disease_df
# Out:
#                              SPECIES NAME AND SYNONYMYS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Physoderma alfalfae (Pat. & Lagerh.) Karling 1950
# 5         ≡ Cladochytrium alfalfae Pat. & Lagerh. 1895
# 6     ≡ Urophlyctis alfalfae (Pat. & Lagerh.) Magnus...
# 7                Physoderma maydis (Miyabe) Miyabe 1909
# 8                   ≡ Cladochytrium maydis Miyabe 1903
# 9              = Physoderma zeae-maydis F.J. Shaw 1912
# 10                                                  NaN
# 11                                                  NaN
# 12    Synchytrium endobioticum (Schilb.) Percival 19...
# 13          ≡ Chrysophlyctis endobioticum Schilb. 1896
# 14                    = Synchytrium solani Massee 1910
# 15             Synchytrium dolichi (Cooke) Gaeum. 1927
# 16                       ≡ Aecidium dolichi Cooke 1882
# 17             ≡ Woroninella dolichi (Cooke) Syd. 1914
# 18                                                  NaN
# 19                                                  NaN
# 20         Olpidium brassicae (Woronin) P.A. Dang. 1886
# 21                 ≡ Chytridium brassicae Woronin 1878
# 22                     = Olpidium borzii De Wild. 1893
# 23                = Asterocystis radicis De Wild. 1893
# 24        ≡ Olpidiaster radicis (De Wild.) Pascher 1917
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    Choanephora cucurbitarum (Berk. & Ravenel) Tha...
# 29    ≡ Rhopalomyces cucurbitarum Berk. & Ravenel 1875
# 30              = Choanephora americana A. Möller 1901
# 31                                                  NaN
# 32    Gilbertella persicaria (E.D. Eddy) Hesselt. 1960
# 33             ≡ Choanephora persicaria E.D. Eddy 1925
# 34                                                  NaN
# 35                    Mucor circinelloides Tiegh. 1875
# 36    ≡ Calyptromyces circinelloides (Tiegh.) Sumst....
# 37     ≡ Circinomucor circinelloides (Tiegh.) Arx 1982
# 38            ≡ Mucor circinelloides f. circinelloides
# 39                             = Mucor alternans Tiegh.
# 52                                                  NaN
# 53                                                  NaN
# 54                     fruit rot, tomato, peach, citrus
# 55                                                  NaN
# 56                                                  NaN
# 57                                                  NaN
# 58                                                  NaN
# 59                                                  NaN
# 60                                                  NaN
# 61                                                  NaN
# 62    stigmatomycosis of beans, citrus, mustard, tom...
# 63                                                  NaN
# 64         stigmatomycosis, internal boll rot of cotton
# 65                                                  NaN
# 66                                                  NaN
# 67                                                  NaN
# 68                                                  NaN
# 69                                                  NaN
# 70                                                  NaN
# 71                            leaf spot, blister of oak
# 72                                                  NaN
# 73                                                  NaN
# 74                                                  NaN
# ...                                                 ...
# 2544                         Downy mildew of sugar cane
# 2545           Downy mildew of sorghum millet and maize
# 2546  Downy mildew of sugar cane and maize          ...
# 2547                      downy mildew of vcoomon poppy
# 2548                              downy mildew of basil
# 2549                              downy mildew of onion
# 2550                            downy mildew of spinach
# 2551         Downy mildew of Mecanopsis and opium poppy
# 2552                                downy mildew of pea
# 2553              downy mildew of Chrysamthemum flowers
# 2554         downy mildew of sugar beet and swiss chard
# 2555                 downy mildew of Mediterranean sage
# 2556                        downy mildew of opium poppy
# 2557                                                NaN
# 2558                                  rose downy mildew
# 2559                            downy mildew of tobacco
# 2560                             Downy mildew of clover
# 2561                     downy mildew of lamb’s lettuce
# 2562                             downy mildew of quinoa
# 2563                         downy mildew of Viola spp.
# 2564                          downy mildew of sunflower
# 2565                         downy mildew of Boston ivy
# 2566                         downy mildew of balsamines
# 2567                            downy mildew of parsley
# 2568                              downy mildew of grape
# 2569                          downy mildew of curcubits
# 2570                               downy mildew of hops
# 2571        Crazy top of maize, wheat and other cereals
# 2572  crazy top and brown stripe downy mildews of maize
# 2573                                                NaN
# 2574   blossom blight and fruit rot of Litchi chinensis
# 2575                                      alder dieback
# 2576  cactus dieback, pathogen of apples, strawberri...
# 2577                   ink disease of European chestnut
# 2578                         pepper and cucurbit blight
# 2579   Phytophthora dieback of various trees and shrubs
# 2580                                   taro leaf blight
# 2581            Phytophthora rot of various ornamentals
# 2582               Phytopthora dieback of various hosts
# 2583                          Pink root rot of potatoes
# 2584                                                NaN
# 2585                                                NaN
# 2586                    Red stele or red core root rot.
# 2587                                                NaN
# 2588  potato, tomato late blight; many important spe...
# 2589  Phytophthora blight on various hosts, reports ...
# 2590          Phytophthora blight of various vegetables
# 2591                                   Sudden oak death
# 2592                                         Citrus rot
# 2593           Blight, damping off, root and other rots
# 2594                                                NaN
# 2595                                                NaN
# 2596                                                NaN
# 2597                                                NaN
# 2598       damping-off of various crops and ornamentals
# 2599                                                NaN
# 2600  seed rots, damping-off, seedling blights, wate...
# 2601                                                NaN
# 2602                                                NaN
# 2603                    root rots of alflafa, beet, pea
# 2604                          root disease of sugarcane
# 2605                                                NaN
# 2606                                                NaN
# 2607                                                NaN
# 2608                                                NaN
# 2609                              clubroot of crucifers
# 2610     root diseases of grasses, beets, virus vectors
# 2611                             powdery scab of potato
# 2612                                                NaN
# 2613                                                NaN
# 2614                                                NaN
# 2615                                                NaN
# 2616                                                NaN
# 2617                                                NaN
# 2618                                                NaN
#
# [2619 rows x 2 columns]

# %% [markdown]
# #### Create a new series from one column of a dataframe

# %%
species_sr = excel_df['SPECIES NAME AND SYNONYMYS']
species_sr
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       Physoderma alfalfae (Pat. & Lagerh.) Karling 1950
# 5           ≡ Cladochytrium alfalfae Pat. & Lagerh. 1895
# 6       ≡ Urophlyctis alfalfae (Pat. & Lagerh.) Magnus...
# 7                  Physoderma maydis (Miyabe) Miyabe 1909
# 8                     ≡ Cladochytrium maydis Miyabe 1903
# 9                = Physoderma zeae-maydis F.J. Shaw 1912
# 10                                                    NaN
# 11                                                    NaN
# 12      Synchytrium endobioticum (Schilb.) Percival 19...
# 13            ≡ Chrysophlyctis endobioticum Schilb. 1896
# 14                      = Synchytrium solani Massee 1910
# 15               Synchytrium dolichi (Cooke) Gaeum. 1927
# 16                         ≡ Aecidium dolichi Cooke 1882
# 17               ≡ Woroninella dolichi (Cooke) Syd. 1914
# 18                                                    NaN
# 19                                                    NaN
# 20           Olpidium brassicae (Woronin) P.A. Dang. 1886
# 21                   ≡ Chytridium brassicae Woronin 1878
# 22                       = Olpidium borzii De Wild. 1893
# 23                  = Asterocystis radicis De Wild. 1893
# 24          ≡ Olpidiaster radicis (De Wild.) Pascher 1917
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28      Choanephora cucurbitarum (Berk. & Ravenel) Tha...
# 29      ≡ Rhopalomyces cucurbitarum Berk. & Ravenel 1875
# 30                = Choanephora americana A. Möller 1901
# 31                                                    NaN
# 32      Gilbertella persicaria (E.D. Eddy) Hesselt. 1960
# 33               ≡ Choanephora persicaria E.D. Eddy 1925
# 34                                                    NaN
# 35                      Mucor circinelloides Tiegh. 1875
# 36      ≡ Calyptromyces circinelloides (Tiegh.) Sumst....
# 37       ≡ Circinomucor circinelloides (Tiegh.) Arx 1982
# 38              ≡ Mucor circinelloides f. circinelloides
# 39                               = Mucor alternans Tiegh.
# 40                   = Mucor ambiguus Vuill. 1887 [1886]
# 41                         = Mucor javanicus Wehmer 1900
# 42              = Mucor prainii Chodat & Nechitsche 1904
# 43                           Mucor racemosus Fresen. 1850
# 44       Rhizopus stolonifer (Ehrenb. : Fr.) Vuill. 1902
# 45                       ≡ Mucor stolonifer Ehrenb. 1818
# 46                      = Rhizopus artocarpi Racib. 1959
# 47                         = Rhizopus necans Massee 1897
# 48                     = Rhizopus nigricans Ehrenb. 1821
# 49      = Rhizopus nigricans var. luxurians J. Schröt....
# 50                                                    NaN
# 51                                                    NaN
# 52                                                    NaN
# 53                                                    NaN
# 54                          Geotrichum candidum Link 1809
# 55      = Endomyces geotrichum E.E. Butler & L.J. Pete...
# 56      ≡ Galactomyces geotrichum (E.E. Butler & L.J. ...
# 57      ≡ Dipodascus geotrichum (E.E. Butler & L.J. Pe...
# 58                 = Oospora lactis (Fresen.) Sacc. 1886
# 59      = Oospora lactis var. parasitica Pritchard & P...
# 60       = Galactomyces candidum de Hoog & M.T. Sm. 2004
# 61                                                    NaN
# 62             Eremothecium coryi (Peglion) Kurtzman 1995
# 63                      ≡ Nematospora coryli Peglion 1901
# 64      Eremothecium gossypii (S.F. Ashby & Nowell) Ku...
# 2594                  ≡ Pythium irregulare Buisman 1927
# 2595                      = Pythium fabae G. Cheney 1932
# 2596    = Pythium irregulare var. hawaiiense Sideris 1...
# 2597                  = Pythium polymorphon Sideris 1932
# 2598                Pythium aphanidermatum (Edson) Fitzp.
# 2599                                                  NaN
# 2600                                 Pythium ultimum Trow
# 2601                                                  NaN
# 2602                                                  NaN
# 2603                      Aphanomyces euteiches Drechsler
# 2604                  Pachymetra chaunorhiza Croft & Dick
# 2605                                                  NaN
# 2606                                                  NaN
# 2607                                                  NaN
# 2608                                                  NaN
# 2609                 Plasmodiophora brassicae Woron. 1877
# 2610                           Polymyxa betae Keskin 1964
# 2611        Spongospora subterranea (Wallr.) Lagerh. 1892
# 2612                   ≡ Erysibe subterranea Wallr. 1842
# 2613                     = Tuburcinia scabies Berk. 1846
# 2614           ≡ Spongospora scabies (Berk.) Massee 1908
# 2615    ≡ Sorosporium scabies (Berk.) A.A. Fisch. Wald...
# 2616                    = Spongospora solani Brunch. 1887
# 2617                 = Protomyces tuber-solani Mart. 1842
# 2618                                                  NaN
# Name: SPECIES NAME AND SYNONYMYS, Length: 2619, dtype: object

# %%
arr = []
arr.append([])
arr[0].append('aa1')
arr[0].append('aa2')
arr
# Out:
# [['aa1', 'aa2']]

# %%
import numpy as np

# %%
df = np.DataFrame(arr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-9da95df96805> in <module>()
# ----> 1 df = np.DataFrame(arr)
#
# AttributeError: module 'numpy' has no attribute 'DataFrame'

# %% [markdown]
# ## Duplicates

# %%
df = pd.read_excel("test_data/duplicates.xlsx")
df
# Out:
#                                   taxon_name  \
# 0                        Abortiporus biennis
# 1                          Polyporus biennis
# 2                            Absidia anomala
# 3                            Absidia anomala
# 4                       Absidia blakesleeana
# 5                        Absidia californica
# 6                        Abortiporus biennis
# 7                        Absidia corymbifera
# 8                         Absidia cuneospora
# 9   Absidia cylindrospora var. cylindrospora
# 10          Absidia cylindrospora var. nigra
# 11    Absidia cylindrospora var. rhizomorpha
# 12                       Absidia californica
# 13                            Absidia glauca
# 14                          Absidia gracilis
# 15                          Absidia griseola
# 16                       Absidia hesseltinei
# 17                       Abortiporus biennis
#
#                           current_taxon_name                    authors  \
# 0                                          -             (Bull.) Singer
# 1                        Abortiporus biennis           (Bulliard) Fries
# 2                                          -    Hesseltine & J.J. Ellis
# 3                                        NaN    H. Naganishi & Hirahara
# 4                     Lichtheimia hyalospora                    Lendner
# 5                        Absidia californica    J.J. Ellis & Hesseltine
# 6                           Absidia coerulea                    Bainier
# 7                    Lichtheimia corymbifera  (Cohn) Saccardo & Trotter
# 8                         Absidia cuneospora        G.F. Orr & Plunkett
# 9   Absidia cylindrospora var. cylindrospora                        NaN
# 10          Absidia cylindrospora var. nigra    Hesseltine & J.J. Ellis
# 11    Absidia cylindrospora var. rhizomorpha    Hesseltine & J.J. Ellis
# 12                       Absidia californica                  Linnemann
# 13                            Absidia glauca                      Hagem
# 14                   Lichtheimia corymbifera                  Linnemann
# 15                          Absidia griseola    H. Naganishi & Hirahara
# 16                   Lichtheimia corymbifera              B.S. Mehrotra
# 17                       Absidia heterospora                    Y. Ling
#
#            source
# 0        MycoBank
# 1        MycoBank
# 2        MycoBank
# 3   IndexFungorum
# 4        MycoBank
# 5        MycoBank
# 6   IndexFungorum
# 7        MycoBank
# 8        MycoBank
# 9        MycoBank
# 10       MycoBank
# 11       MycoBank
# 12           ICTF
# 13       MycoBank
# 14       MycoBank
# 15       MycoBank
# 16       MycoBank
# 17           ICTF

# %%
df_dupl = df.duplicated('taxon_name', keep=False)

# %%
df.insert(loc=4, column='taxon_name duplicated', value=df_dupl)
df
# Out:
#                                   taxon_name  \
# 0                        Abortiporus biennis
# 1                          Polyporus biennis
# 2                            Absidia anomala
# 3                            Absidia anomala
# 4                       Absidia blakesleeana
# 5                        Absidia californica
# 6                        Abortiporus biennis
# 7                        Absidia corymbifera
# 8                         Absidia cuneospora
# 9   Absidia cylindrospora var. cylindrospora
# 10          Absidia cylindrospora var. nigra
# 11    Absidia cylindrospora var. rhizomorpha
# 12                       Absidia californica
# 13                            Absidia glauca
# 14                          Absidia gracilis
# 15                          Absidia griseola
# 16                       Absidia hesseltinei
# 17                       Abortiporus biennis
#
#                           current_taxon_name                    authors  \
# 0                                          -             (Bull.) Singer
# 1                        Abortiporus biennis           (Bulliard) Fries
# 2                                          -    Hesseltine & J.J. Ellis
# 3                                        NaN    H. Naganishi & Hirahara
# 4                     Lichtheimia hyalospora                    Lendner
# 5                        Absidia californica    J.J. Ellis & Hesseltine
# 6                           Absidia coerulea                    Bainier
# 7                    Lichtheimia corymbifera  (Cohn) Saccardo & Trotter
# 8                         Absidia cuneospora        G.F. Orr & Plunkett
# 9   Absidia cylindrospora var. cylindrospora                        NaN
# 10          Absidia cylindrospora var. nigra    Hesseltine & J.J. Ellis
# 11    Absidia cylindrospora var. rhizomorpha    Hesseltine & J.J. Ellis
# 12                       Absidia californica                  Linnemann
# 13                            Absidia glauca                      Hagem
# 14                   Lichtheimia corymbifera                  Linnemann
# 15                          Absidia griseola    H. Naganishi & Hirahara
# 16                   Lichtheimia corymbifera              B.S. Mehrotra
# 17                       Absidia heterospora                    Y. Ling
#
#            source  taxon_name duplicated
# 0        MycoBank                   True
# 1        MycoBank                  False
# 2        MycoBank                   True
# 3   IndexFungorum                   True
# 4        MycoBank                  False
# 5        MycoBank                   True
# 6   IndexFungorum                   True
# 7        MycoBank                  False
# 8        MycoBank                  False
# 9        MycoBank                  False
# 10       MycoBank                  False
# 11       MycoBank                  False
# 12           ICTF                   True
# 13       MycoBank                  False
# 14       MycoBank                  False
# 15       MycoBank                  False
# 16       MycoBank                  False
# 17           ICTF                   True

# %%
unique_names = df['taxon_name'].unique()
unique_names.sort()
unique_names
# Out:
# array(['Abortiporus biennis', 'Absidia anomala', 'Absidia blakesleeana',
#        'Absidia californica', 'Absidia corymbifera', 'Absidia cuneospora',
#        'Absidia cylindrospora var. cylindrospora',
#        'Absidia cylindrospora var. nigra',
#        'Absidia cylindrospora var. rhizomorpha', 'Absidia glauca',
#        'Absidia gracilis', 'Absidia griseola', 'Absidia hesseltinei',
#        'Polyporus biennis'], dtype=object)

# %%
for name in unique_names:
    group = df.loc[df['taxon_name'] == name]
    new_group = group.drop_duplicates('current_taxon_name')
    print(new_group)
    print('--------------------')
# Out:
#              taxon_name   current_taxon_name         authors         source  \
# 0   Abortiporus biennis                    -  (Bull.) Singer       MycoBank
# 6   Abortiporus biennis     Absidia coerulea         Bainier  IndexFungorum
# 17  Abortiporus biennis  Absidia heterospora         Y. Ling           ICTF
#
#     taxon_name duplicated
# 0                    True
# 6                    True
# 17                   True
# --------------------
#         taxon_name current_taxon_name                  authors         source  \
# 2  Absidia anomala                  -  Hesseltine & J.J. Ellis       MycoBank
# 3  Absidia anomala                NaN  H. Naganishi & Hirahara  IndexFungorum
#
#    taxon_name duplicated
# 2                   True
# 3                   True
# --------------------
#              taxon_name      current_taxon_name  authors    source  \
# 4  Absidia blakesleeana  Lichtheimia hyalospora  Lendner  MycoBank
#
#    taxon_name duplicated
# 4                  False
# --------------------
#             taxon_name   current_taxon_name                  authors  \
# 5  Absidia californica  Absidia californica  J.J. Ellis & Hesseltine
#
#      source  taxon_name duplicated
# 5  MycoBank                   True
# --------------------
#             taxon_name       current_taxon_name                    authors  \
# 7  Absidia corymbifera  Lichtheimia corymbifera  (Cohn) Saccardo & Trotter
#
#      source  taxon_name duplicated
# 7  MycoBank                  False
# --------------------
#            taxon_name  current_taxon_name              authors    source  \
# 8  Absidia cuneospora  Absidia cuneospora  G.F. Orr & Plunkett  MycoBank
#
#    taxon_name duplicated
# 8                  False
# --------------------
#                                  taxon_name  \
# 9  Absidia cylindrospora var. cylindrospora
#
#                          current_taxon_name authors    source  \
# 9  Absidia cylindrospora var. cylindrospora     NaN  MycoBank
#
#    taxon_name duplicated
# 9                  False
# --------------------
#                           taxon_name                current_taxon_name  \
# 10  Absidia cylindrospora var. nigra  Absidia cylindrospora var. nigra
#
#                     authors    source  taxon_name duplicated
# 10  Hesseltine & J.J. Ellis  MycoBank                  False
# --------------------
#                                 taxon_name  \
# 11  Absidia cylindrospora var. rhizomorpha
#
#                         current_taxon_name                  authors    source  \
# 11  Absidia cylindrospora var. rhizomorpha  Hesseltine & J.J. Ellis  MycoBank
#
#     taxon_name duplicated
# 11                  False
# --------------------
#         taxon_name current_taxon_name authors    source  taxon_name duplicated
# 13  Absidia glauca     Absidia glauca   Hagem  MycoBank                  False
# --------------------
#           taxon_name       current_taxon_name    authors    source  \
# 14  Absidia gracilis  Lichtheimia corymbifera  Linnemann  MycoBank
#
#     taxon_name duplicated
# 14                  False
# --------------------
#           taxon_name current_taxon_name                  authors    source  \
# 15  Absidia griseola   Absidia griseola  H. Naganishi & Hirahara  MycoBank
#
#     taxon_name duplicated
# 15                  False
# --------------------
#              taxon_name       current_taxon_name        authors    source  \
# 16  Absidia hesseltinei  Lichtheimia corymbifera  B.S. Mehrotra  MycoBank
#
#     taxon_name duplicated
# 16                  False
# --------------------
#           taxon_name   current_taxon_name           authors    source  \
# 1  Polyporus biennis  Abortiporus biennis  (Bulliard) Fries  MycoBank
#
#    taxon_name duplicated
# 1                  False
# --------------------

# %%
# Convert column format
#pd.to_numeric(agr_land_area['Value'])
