# %% [markdown]
# # FTP Cheatsheet
#
# Here so far:
# * Access
# * Check connection
# * Download a file

# %% [markdown]
# ## ftplib
#
# My preferred way to access stuff online is using requests, however requests only deals with http(s) protocols. So for ftp access I have used ftplib. Why? Seems to be most commonly used and basic. If I run into problems and will need a better library for ftp download, then it will be here as well.
#
# _Don't forget to close the connection!!!_

# %% [markdown]
# ### Connect and check connection.

# %%
import ftplib

connection_successful = False

try:
    ftp = ftplib.FTP('ftp.ncbi.nlm.nih.gov')
    ftp.login(user='anonymous', passwd='anonymous')
    ftp.cwd('blast/db/')

    # Just to check the connection. Does nothing
    response = ftp.voidcmd('NOOP')
    
    if response == '200 NOOP command successful':
        connection_successful = True
    
    ftp.quit()
except IOError as e:
    # Get here if there is:
    ##  no connection (turned off wifi)
    ##  time out: when I use vpn from home and ncbi is not accessible
    print('FTP access error. Error: {}'.format(e))
except ftplib.error_temp as e:
    # Get here if there is:
    ##  idle timeout - ftp was closed for not being used
    print('FTP connection error. Error: {}'.format(e))

except ftplib.socket.timeout as e:
    # Don't get here 
    print("Request timed out. Error: {}".format(e))
except ftplib.error_perm as e:
    # Get here if :
    ##  ftp directory does not exist  (programmer's error)
    ## command sent is not recognized (programmer's error)
    print("FTP error. {}".format(e))
    ftp.quit()
except:
    # Get here if:
    ## I put a syntax error in the try block, like a line "blah" (programmer's error)
    print("Something went wrong when connecting to ftp.")
    ftp.quit()
    
connection_successful
# Out:
# Something went wrong when connecting to ftp.
# True

# %% [markdown]
# ### List files in ftp directory
#
# If this throws exceptions, see the code above for testing connection for exception handling

# %%
import ftplib

ftp = ftplib.FTP('ftp.ncbi.nlm.nih.gov')
ftp.login(user='anonymous', passwd='anonymous')
ftp.cwd('blast/db/')

#data = []
#ftp.dir(data.append)
#ftp.quit()
#data

files = ftp.nlst()
ftp.quit()
files
# Out:
# ['README',
#  'FASTA',
#  'human_genomic.00.tar.gz.md5',
#  'env_nr.00.tar.gz',
#  'env_nr.00.tar.gz.md5',
#  'env_nr.01.tar.gz',
#  'env_nr.01.tar.gz.md5',
#  'env_nt.00.tar.gz',
#  'env_nt.00.tar.gz.md5',
#  'env_nt.01.tar.gz',
#  'env_nt.01.tar.gz.md5',
#  'env_nt.02.tar.gz',
#  'env_nt.02.tar.gz.md5',
#  'est.tar.gz',
#  'est.tar.gz.md5',
#  'est_human.00.tar.gz',
#  'est_human.00.tar.gz.md5',
#  'est_human.01.tar.gz',
#  'est_human.01.tar.gz.md5',
#  'est_mouse.tar.gz',
#  'est_mouse.tar.gz.md5',
#  'est_others.00.tar.gz',
#  'est_others.00.tar.gz.md5',
#  'est_others.01.tar.gz',
#  'est_others.01.tar.gz.md5',
#  'est_others.02.tar.gz',
#  'est_others.02.tar.gz.md5',
#  'est_others.03.tar.gz',
#  'est_others.03.tar.gz.md5',
#  'est_others.04.tar.gz',
#  'est_others.04.tar.gz.md5',
#  'est_others.05.tar.gz',
#  'est_others.05.tar.gz.md5',
#  'est_others.06.tar.gz',
#  'est_others.06.tar.gz.md5',
#  'est_others.07.tar.gz',
#  'est_others.07.tar.gz.md5',
#  'est_others.08.tar.gz',
#  'est_others.08.tar.gz.md5',
#  'est_others.09.tar.gz',
#  'est_others.09.tar.gz.md5',
#  'gss.00.tar.gz',
#  'gss.00.tar.gz.md5',
#  'gss.01.tar.gz',
#  'gss.01.tar.gz.md5',
#  'gss.02.tar.gz',
#  'gss.02.tar.gz.md5',
#  'gss.03.tar.gz',
#  'gss.03.tar.gz.md5',
#  'gss.04.tar.gz',
#  'gss.04.tar.gz.md5',
#  'gss.05.tar.gz',
#  'gss.05.tar.gz.md5',
#  'htgs.00.tar.gz',
#  'htgs.00.tar.gz.md5',
#  'htgs.01.tar.gz',
#  'htgs.01.tar.gz.md5',
#  'htgs.02.tar.gz',
#  'htgs.02.tar.gz.md5',
#  'htgs.03.tar.gz',
#  'htgs.03.tar.gz.md5',
#  'htgs.04.tar.gz',
#  'htgs.04.tar.gz.md5',
#  'htgs.05.tar.gz',
#  'htgs.05.tar.gz.md5',
#  'htgs.06.tar.gz',
#  'htgs.06.tar.gz.md5',
#  'htgs.07.tar.gz',
#  'htgs.07.tar.gz.md5',
#  'htgs.08.tar.gz',
#  'htgs.08.tar.gz.md5',
#  'htgs.09.tar.gz',
#  'htgs.09.tar.gz.md5',
#  'human_genomic.00.tar.gz',
#  'human_genomic.01.tar.gz.md5',
#  'human_genomic.01.tar.gz',
#  'human_genomic.02.tar.gz.md5',
#  'human_genomic.02.tar.gz',
#  'human_genomic.03.tar.gz.md5',
#  'human_genomic.03.tar.gz',
#  'human_genomic.04.tar.gz.md5',
#  'human_genomic.04.tar.gz',
#  'human_genomic.05.tar.gz.md5',
#  'human_genomic.05.tar.gz',
#  'human_genomic.06.tar.gz.md5',
#  'human_genomic.06.tar.gz',
#  'human_genomic.07.tar.gz.md5',
#  'human_genomic.07.tar.gz',
#  'human_genomic.08.tar.gz.md5',
#  'human_genomic.08.tar.gz',
#  'other_genomic.00.tar.gz.md5',
#  'nr.00.tar.gz',
#  'nr.00.tar.gz.md5',
#  'v5',
#  'nr.83.tar.gz',
#  'nr.75.tar.gz',
#  'nr.75.tar.gz.md5',
#  'nr.01.tar.gz',
#  'nr.01.tar.gz.md5',
#  'nr.02.tar.gz',
#  'nr.02.tar.gz.md5',
#  'nr.03.tar.gz',
#  'nr.03.tar.gz.md5',
#  'nr.04.tar.gz',
#  'nr.04.tar.gz.md5',
#  'nr.05.tar.gz',
#  'nr.05.tar.gz.md5',
#  'nt.00.tar.gz',
#  'nt.00.tar.gz.md5',
#  'nt.01.tar.gz',
#  'nt.01.tar.gz.md5',
#  'nt.02.tar.gz',
#  'nt.02.tar.gz.md5',
#  'nt.03.tar.gz',
#  'nt.03.tar.gz.md5',
#  'nt.04.tar.gz',
#  'nt.04.tar.gz.md5',
#  'nt.05.tar.gz',
#  'nt.05.tar.gz.md5',
#  'nt.06.tar.gz',
#  'nt.06.tar.gz.md5',
#  'nt.07.tar.gz',
#  'nt.07.tar.gz.md5',
#  'nt.08.tar.gz',
#  'nt.08.tar.gz.md5',
#  'nt.09.tar.gz',
#  'nt.09.tar.gz.md5',
#  'nt.10.tar.gz',
#  'nt.10.tar.gz.md5',
#  'other_genomic.00.tar.gz',
#  'other_genomic.01.tar.gz.md5',
#  'other_genomic.01.tar.gz',
#  'other_genomic.02.tar.gz.md5',
#  'other_genomic.02.tar.gz',
#  'other_genomic.03.tar.gz.md5',
#  'other_genomic.03.tar.gz',
#  'other_genomic.04.tar.gz.md5',
#  'other_genomic.04.tar.gz',
#  'other_genomic.05.tar.gz.md5',
#  'other_genomic.05.tar.gz',
#  'other_genomic.06.tar.gz.md5',
#  'other_genomic.06.tar.gz',
#  'other_genomic.07.tar.gz.md5',
#  'other_genomic.07.tar.gz',
#  'other_genomic.08.tar.gz.md5',
#  'other_genomic.08.tar.gz',
#  'other_genomic.09.tar.gz.md5',
#  'other_genomic.09.tar.gz',
#  'other_genomic.10.tar.gz.md5',
#  'other_genomic.10.tar.gz',
#  'other_genomic.11.tar.gz.md5',
#  'other_genomic.11.tar.gz',
#  'other_genomic.12.tar.gz.md5',
#  'other_genomic.12.tar.gz',
#  'other_genomic.13.tar.gz.md5',
#  'other_genomic.13.tar.gz',
#  'other_genomic.14.tar.gz.md5',
#  'pataa.tar.gz',
#  'pataa.tar.gz.md5',
#  'patnt.00.tar.gz',
#  'patnt.00.tar.gz.md5',
#  'patnt.01.tar.gz',
#  'patnt.01.tar.gz.md5',
#  'patnt.02.tar.gz',
#  'patnt.02.tar.gz.md5',
#  'pdbnt.00.tar.gz',
#  'cdd_delta.tar.gz',
#  'nr.76.tar.gz',
#  'nr.16.tar.gz',
#  'other_genomic.14.tar.gz',
#  'other_genomic.15.tar.gz.md5',
#  'nr.76.tar.gz.md5',
#  'refseq_genomic.218.tar.gz',
#  'nr.54.tar.gz',
#  'refseq_genomic.218.tar.gz.md5',
#  'nr.54.tar.gz.md5',
#  'refseq_genomic.219.tar.gz',
#  'pdbnt.40.tar.gz',
#  'refseq_rna.00.tar.gz',
#  'refseq_rna.00.tar.gz.md5',
#  'refseq_rna.01.tar.gz',
#  'refseq_rna.01.tar.gz.md5',
#  'other_genomic.15.tar.gz',
#  'refseq_genomic.00.tar.gz.md5',
#  'refseq_genomic.219.tar.gz.md5',
#  'nt.40.tar.gz',
#  'refseq_genomic.220.tar.gz',
#  'nt.40.tar.gz.md5',
#  'gene_info.tgz',
#  'refseq_genomic.220.tar.gz.md5',
#  'nr.55.tar.gz',
#  'other_genomic.19.tar.gz',
#  'nr.55.tar.gz.md5',
#  'nt.11.tar.gz',
#  'nr.56.tar.gz',
#  'refseq_protein.25.tar.gz',
#  '16SMicrobial.tar.gz',
#  'nr.56.tar.gz.md5',
#  '16SMicrobial.tar.gz.md5',
#  'refseq_protein.25.tar.gz.md5',
#  'nr.06.tar.gz',
#  'sts.tar.gz.md5',
#  'refseq_genomic.00.tar.gz',
#  'refseq_genomic.01.tar.gz.md5',
#  'refseq_genomic.01.tar.gz',
#  'refseq_genomic.02.tar.gz.md5',
#  'refseq_genomic.02.tar.gz',
#  'refseq_genomic.03.tar.gz.md5',
#  'refseq_genomic.03.tar.gz',
#  'refseq_genomic.04.tar.gz.md5',
#  'refseq_genomic.04.tar.gz',
#  'refseq_genomic.05.tar.gz.md5',
#  'refseq_genomic.05.tar.gz',
#  'refseq_genomic.06.tar.gz.md5',
#  'refseq_genomic.06.tar.gz',
#  'refseq_genomic.07.tar.gz.md5',
#  'refseq_genomic.07.tar.gz',
#  'refseq_genomic.08.tar.gz.md5',
#  'refseq_genomic.08.tar.gz',
#  'refseq_genomic.09.tar.gz.md5',
#  'refseq_genomic.09.tar.gz',
#  'refseq_genomic.10.tar.gz.md5',
#  'refseq_genomic.10.tar.gz',
#  'refseq_genomic.11.tar.gz.md5',
#  'refseq_genomic.11.tar.gz',
#  'refseq_genomic.12.tar.gz.md5',
#  'refseq_genomic.12.tar.gz',
#  'refseq_genomic.13.tar.gz.md5',
#  'refseq_genomic.13.tar.gz',
#  'refseq_genomic.14.tar.gz.md5',
#  'refseq_genomic.14.tar.gz',
#  'refseq_genomic.15.tar.gz.md5',
#  'refseq_genomic.15.tar.gz',
#  'refseq_genomic.16.tar.gz.md5',
#  'refseq_genomic.16.tar.gz',
#  'refseq_genomic.17.tar.gz.md5',
#  'refseq_genomic.17.tar.gz',
#  'refseq_genomic.18.tar.gz.md5',
#  'refseq_genomic.18.tar.gz',
#  'refseq_genomic.19.tar.gz.md5',
#  'refseq_genomic.19.tar.gz',
#  'refseq_genomic.20.tar.gz.md5',
#  'refseq_genomic.20.tar.gz',
#  'refseq_genomic.21.tar.gz.md5',
#  'refseq_genomic.21.tar.gz',
#  'refseq_protein.00.tar.gz',
#  'refseq_protein.00.tar.gz.md5',
#  'refseq_protein.01.tar.gz',
#  'refseq_protein.01.tar.gz.md5',
#  'refseq_protein.02.tar.gz',
#  'refseq_protein.02.tar.gz.md5',
#  'refseq_protein.03.tar.gz',
#  'refseq_protein.03.tar.gz.md5',
#  'refseq_genomic.22.tar.gz',
#  'refseq_genomic.22.tar.gz.md5',
#  'refseqgene.tar.gz',
#  'refseqgene.tar.gz.md5',
#  'sts.tar.gz',
#  'taxdb.tar.gz.md5',
#  'nr.07.tar.gz.md5',
#  'nt.12.tar.gz.md5',
#  'nr.15.tar.gz',
#  'nr.30.tar.gz',
#  'taxdb.tar.gz',
#  'nt.41.tar.gz',
#  'tsa_nt.00.tar.gz',
#  'refseq_genomic.221.tar.gz',
#  'vector.tar.gz',
#  'vector.tar.gz.md5',
#  'refseq_genomic.221.tar.gz.md5',
#  'pdbnt.40.tar.gz.md5',
#  'refseq_genomic.222.tar.gz',
#  'refseq_genomic.222.tar.gz.md5',
#  'refseq_genomic.223.tar.gz',
#  'refseq_genomic.223.tar.gz.md5',
#  'refseq_protein.26.tar.gz',
#  'refseq_protein.26.tar.gz.md5',
#  'refseq_genomic.224.tar.gz',
#  'refseq_genomic.224.tar.gz.md5',
#  'refseq_genomic.225.tar.gz',
#  'refseq_genomic.225.tar.gz.md5',
#  'refseq_genomic.226.tar.gz',
#  'refseq_genomic.226.tar.gz.md5',
#  'nt.41.tar.gz.md5',
#  'refseq_genomic.227.tar.gz',
#  'pdbnt.41.tar.gz',
#  'refseq_genomic.227.tar.gz.md5',
#  'nr.57.tar.gz',
#  'refseq_genomic.228.tar.gz',
#  'nr.57.tar.gz.md5',
#  'refseq_genomic.228.tar.gz.md5',
#  'patnt.04.tar.gz',
#  'refseq_genomic.229.tar.gz',
#  'nr.58.tar.gz',
#  'refseq_genomic.229.tar.gz.md5',
#  'nr.58.tar.gz.md5',
#  'pdbnt.41.tar.gz.md5',
#  'nr.59.tar.gz',
#  'refseq_genomic.230.tar.gz',
#  'nr.59.tar.gz.md5',
#  'refseq_genomic.230.tar.gz.md5',
#  'nt.42.tar.gz',
#  'ref_prok_rep_genomes.00.tar.gz',
#  'nt.42.tar.gz.md5',
#  'ref_prok_rep_genomes.01.tar.gz',
#  'pdbnt.42.tar.gz',
#  'ref_prok_rep_genomes.02.tar.gz',
#  'nr.60.tar.gz',
#  'ref_prok_rep_genomes.03.tar.gz',
#  'nr.60.tar.gz.md5',
#  'ref_prok_rep_genomes.04.tar.gz',
#  'nt.43.tar.gz',
#  'ref_prok_rep_genomes.05.tar.gz',
#  'nt.43.tar.gz.md5',
#  'ref_viruses_rep_genomes.tar.gz',
#  'pdbnt.43.tar.gz',
#  'ref_viroids_rep_genomes.tar.gz',
#  'nr.61.tar.gz',
#  'patnt.04.tar.gz.md5',
#  'nr.61.tar.gz.md5',
#  'refseq_genomic.231.tar.gz',
#  'nt.44.tar.gz',
#  'refseq_genomic.231.tar.gz.md5',
#  'nt.44.tar.gz.md5',
#  'refseq_genomic.232.tar.gz',
#  'pdbnt.44.tar.gz',
#  'refseq_genomic.232.tar.gz.md5',
#  'nr.62.tar.gz',
#  'refseq_protein.27.tar.gz',
#  'nr.62.tar.gz.md5',
#  'refseq_protein.27.tar.gz.md5',
#  'nr.63.tar.gz',
#  'pdbnt.42.tar.gz.md5',
#  'nr.63.tar.gz.md5',
#  'refseq_rna.10.tar.gz',
#  'nr.64.tar.gz',
#  'refseq_rna.10.tar.gz.md5',
#  'nr.64.tar.gz.md5',
#  'refseq_genomic.233.tar.gz',
#  'pdbnt.45.tar.gz',
#  'refseq_genomic.233.tar.gz.md5',
#  'nt.45.tar.gz',
#  'refseq_genomic.234.tar.gz',
#  'nt.45.tar.gz.md5',
#  'refseq_genomic.234.tar.gz.md5',
#  'nr.65.tar.gz',
#  'refseq_protein.28.tar.gz',
#  'nr.65.tar.gz.md5',
#  'refseq_protein.28.tar.gz.md5',
#  'nr.66.tar.gz',
#  'refseq_genomic.235.tar.gz',
#  'nr.66.tar.gz.md5',
#  'refseq_genomic.235.tar.gz.md5',
#  'nr.67.tar.gz',
#  'refseq_genomic.236.tar.gz',
#  'nr.67.tar.gz.md5',
#  'refseq_genomic.236.tar.gz.md5',
#  'nt.46.tar.gz',
#  'refseq_genomic.237.tar.gz',
#  'nt.46.tar.gz.md5',
#  'refseq_genomic.237.tar.gz.md5',
#  'pdbnt.46.tar.gz',
#  'refseq_genomic.238.tar.gz',
#  'nr.68.tar.gz',
#  'refseq_genomic.238.tar.gz.md5',
#  'nr.68.tar.gz.md5',
#  'refseq_genomic.239.tar.gz',
#  'nt.47.tar.gz',
#  'refseq_genomic.239.tar.gz.md5',
#  'nt.47.tar.gz.md5',
#  'refseq_genomic.240.tar.gz',
#  'pdbnt.47.tar.gz',
#  'refseq_genomic.240.tar.gz.md5',
#  'nr.69.tar.gz',
#  'refseq_genomic.241.tar.gz',
#  'nr.69.tar.gz.md5',
#  'refseq_genomic.241.tar.gz.md5',
#  'nr.70.tar.gz',
#  'refseq_genomic.242.tar.gz',
#  'nr.70.tar.gz.md5',
#  'refseq_genomic.242.tar.gz.md5',
#  'nr.71.tar.gz',
#  'nr.06.tar.gz.md5',
#  'pdbnt.43.tar.gz.md5',
#  'refseq_genomic.243.tar.gz',
#  'nr.71.tar.gz.md5',
#  'refseq_genomic.243.tar.gz.md5',
#  'pdbnt.48.tar.gz',
#  'nt.11.tar.gz.md5',
#  'ref_prok_rep_genomes.00.tar.gz.md5',
#  'refseq_protein.29.tar.gz',
#  'refseq_protein.29.tar.gz.md5',
#  'refseq_genomic.23.tar.gz',
#  'refseq_genomic.28.tar.gz.md5',
#  'nt.48.tar.gz',
#  'refseq_genomic.244.tar.gz',
#  'refseq_genomic.24.tar.gz',
#  'refseq_genomic.29.tar.gz.md5',
#  'refseq_genomic.25.tar.gz',
#  'refseq_genomic.30.tar.gz.md5',
#  'refseq_genomic.26.tar.gz',
#  'refseq_genomic.31.tar.gz.md5',
#  'refseq_genomic.27.tar.gz',
#  'refseq_genomic.32.tar.gz.md5',
#  'refseq_genomic.28.tar.gz',
#  'refseq_genomic.33.tar.gz.md5',
#  'refseq_genomic.29.tar.gz',
#  'refseq_genomic.34.tar.gz.md5',
#  'refseq_genomic.30.tar.gz',
#  'refseq_genomic.35.tar.gz.md5',
#  'refseq_genomic.31.tar.gz',
#  'refseq_genomic.36.tar.gz.md5',
#  'refseq_genomic.32.tar.gz',
#  'env_nt.03.tar.gz.md5',
#  'refseq_genomic.33.tar.gz',
#  'tsa_nt.01.tar.gz.md5',
#  'refseq_genomic.34.tar.gz',
#  'other_genomic.17.tar.gz.md5',
#  'refseq_genomic.35.tar.gz',
#  'other_genomic.18.tar.gz.md5',
#  'refseq_genomic.36.tar.gz',
#  'refseq_genomic.244.tar.gz.md5',
#  'refseq_genomic.37.tar.gz.md5',
#  'refseq_genomic.245.tar.gz',
#  'refseq_genomic.245.tar.gz.md5',
#  'env_nt.03.tar.gz',
#  'pdbnt.44.tar.gz.md5',
#  'other_genomic.16.tar.gz',
#  'refseq_genomic.246.tar.gz',
#  'nt.48.tar.gz.md5',
#  'refseq_genomic.246.tar.gz.md5',
#  'nr.72.tar.gz',
#  'refseq_genomic.247.tar.gz',
#  'nr.72.tar.gz.md5',
#  'refseq_genomic.247.tar.gz.md5',
#  'pdbnt.49.tar.gz',
#  'refseq_genomic.248.tar.gz',
#  'refseq_genomic.248.tar.gz.md5',
#  'other_genomic.57.tar.gz',
#  'tsa_nt.01.tar.gz',
#  'tsa_nt.02.tar.gz',
#  'ref_prok_rep_genomes.01.tar.gz.md5',
#  'other_genomic.100.tar.gz',
#  'other_genomic.100.tar.gz.md5',
#  'nt.49.tar.gz',
#  'other_genomic.101.tar.gz',
#  'nt.49.tar.gz.md5',
#  'other_genomic.101.tar.gz.md5',
#  'nr.73.tar.gz',
#  'other_genomic.102.tar.gz',
#  'nr.73.tar.gz.md5',
#  'other_genomic.102.tar.gz.md5',
#  'nt.50.tar.gz',
#  'other_genomic.103.tar.gz',
#  'refseq_genomic.37.tar.gz',
#  'other_genomic.103.tar.gz.md5',
#  'other_genomic.17.tar.gz',
#  'nt.50.tar.gz.md5',
#  'patnt.03.tar.gz',
#  'ref_prok_rep_genomes.02.tar.gz.md5',
#  'pdbnt.50.tar.gz',
#  'refseq_genomic.38.tar.gz.md5',
#  'other_genomic.20.tar.gz.md5',
#  'other_genomic.104.tar.gz',
#  'refseq_genomic.38.tar.gz',
#  'other_genomic.104.tar.gz.md5',
#  'refseq_protein.04.tar.gz',
#  'nr.74.tar.gz',
#  'nr.74.tar.gz.md5',
#  'other_genomic.21.tar.gz.md5',
#  'other_genomic.18.tar.gz',
#  'other_genomic.105.tar.gz',
#  'nr.07.tar.gz',
#  'other_genomic.22.tar.gz.md5',
#  'other_genomic.79.tar.gz',
#  'nr.77.tar.gz',
#  'ref_prok_rep_genomes.03.tar.gz.md5',
#  'nt.12.tar.gz',
#  'nr.77.tar.gz.md5',
#  'other_genomic.57.tar.gz.md5',
#  'other_genomic.23.tar.gz.md5',
#  'other_genomic.24.tar.gz.md5',
#  'other_genomic.20.tar.gz',
#  'other_genomic.25.tar.gz.md5',
#  'other_genomic.21.tar.gz',
#  'other_genomic.26.tar.gz.md5',
#  'other_genomic.22.tar.gz',
#  'other_genomic.27.tar.gz.md5',
#  'other_genomic.23.tar.gz',
#  'other_genomic.105.tar.gz.md5',
#  'other_genomic.24.tar.gz',
#  'other_genomic.106.tar.gz',
#  'other_genomic.25.tar.gz',
#  'other_genomic.106.tar.gz.md5',
#  'other_genomic.26.tar.gz',
#  'other_genomic.107.tar.gz',
#  'other_genomic.27.tar.gz',
#  'nt.51.tar.gz',
#  'nt.51.tar.gz.md5',
#  'other_genomic.107.tar.gz.md5',
#  'pdbnt.51.tar.gz',
#  'refseq_genomic.24.tar.gz.md5',
#  'nr.78.tar.gz',
#  'refseq_genomic.25.tar.gz.md5',
#  'nr.78.tar.gz.md5',
#  'refseq_genomic.26.tar.gz.md5',
#  'nr.08.tar.gz',
#  'env_nt.24.tar.gz',
#  'refseq_genomic.27.tar.gz.md5',
#  'env_nt.25.tar.gz',
#  'refseq_genomic.39.tar.gz.md5',
#  'env_nt.26.tar.gz',
#  'refseq_genomic.40.tar.gz.md5',
#  'env_nt.27.tar.gz',
#  'refseq_genomic.41.tar.gz.md5',
#  'env_nt.28.tar.gz',
#  'refseq_genomic.42.tar.gz.md5',
#  'nt.52.tar.gz',
#  'refseq_genomic.43.tar.gz.md5',
#  'nt.52.tar.gz.md5',
#  'refseq_genomic.44.tar.gz.md5',
#  'refseq_genomic.45.tar.gz.md5',
#  'refseq_protein.04.tar.gz.md5',
#  'human_genomic.10.tar.gz.md5',
#  'nr.08.tar.gz.md5',
#  'other_genomic.16.tar.gz.md5',
#  'other_genomic.108.tar.gz',
#  'refseq_genomic.39.tar.gz',
#  'refseq_genomic.46.tar.gz.md5',
#  'refseq_genomic.40.tar.gz',
#  'refseq_genomic.47.tar.gz.md5',
#  'refseq_genomic.41.tar.gz',
#  'refseq_genomic.48.tar.gz.md5',
#  'refseq_genomic.42.tar.gz',
#  'refseq_genomic.49.tar.gz.md5',
#  'refseq_genomic.43.tar.gz',
#  'human_genomic.10.tar.gz',
#  'refseq_genomic.44.tar.gz',
#  'other_genomic.108.tar.gz.md5',
#  'refseq_genomic.45.tar.gz',
#  'other_genomic.28.tar.gz.md5',
#  'refseq_genomic.48.tar.gz',
#  'tsa_nt.02.tar.gz.md5',
#  'other_genomic.109.tar.gz',
#  'refseq_genomic.23.tar.gz.md5',
#  'refseq_genomic.50.tar.gz.md5',
#  'refseq_genomic.51.tar.gz.md5',
#  'refseq_genomic.46.tar.gz',
#  'other_genomic.28.tar.gz',
#  'refseq_genomic.47.tar.gz',
#  'refseq_genomic.52.tar.gz.md5',
#  'refseq_protein.05.tar.gz.md5',
#  'patnt.03.tar.gz.md5',
#  'nr.09.tar.gz.md5',
#  'ref_prok_rep_genomes.04.tar.gz.md5',
#  'refseq_protein.05.tar.gz',
#  'nr.10.tar.gz.md5',
#  'refseq_genomic.53.tar.gz.md5',
#  'refseq_genomic.49.tar.gz',
#  'nt.13.tar.gz',
#  'nr.09.tar.gz',
#  'nt.13.tar.gz.md5',
#  'other_genomic.29.tar.gz.md5',
#  'nr.11.tar.gz.md5',
#  'refseq_genomic.54.tar.gz.md5',
#  'other_genomic.29.tar.gz',
#  'refseq_genomic.55.tar.gz.md5',
#  'other_genomic.30.tar.gz.md5',
#  'refseq_genomic.50.tar.gz',
#  'refseq_genomic.51.tar.gz',
#  'other_genomic.31.tar.gz.md5',
#  'other_genomic.30.tar.gz',
#  'other_genomic.32.tar.gz.md5',
#  'other_genomic.33.tar.gz.md5',
#  'other_genomic.31.tar.gz',
#  'other_genomic.32.tar.gz',
#  'other_genomic.34.tar.gz.md5',
#  'other_genomic.35.tar.gz.md5',
#  'other_genomic.33.tar.gz',
#  'other_genomic.36.tar.gz.md5',
#  'other_genomic.34.tar.gz',
#  'other_genomic.37.tar.gz.md5',
#  'other_genomic.35.tar.gz',
#  'refseq_genomic.56.tar.gz.md5',
#  'refseq_protein.06.tar.gz.md5',
#  'other_genomic.36.tar.gz',
#  'other_genomic.37.tar.gz',
#  'gss.06.tar.gz.md5',
#  'refseq_genomic.52.tar.gz',
#  'refseq_genomic.57.tar.gz.md5',
#  'refseq_genomic.58.tar.gz.md5',
#  'refseq_protein.06.tar.gz',
#  'refseq_genomic.53.tar.gz',
#  'refseq_genomic.59.tar.gz.md5',
#  'refseq_genomic.54.tar.gz',
#  'gss.06.tar.gz',
#  'nt.14.tar.gz.md5',
#  'refseq_genomic.60.tar.gz.md5',
#  'nr.10.tar.gz',
#  'refseq_genomic.61.tar.gz.md5',
#  'refseq_genomic.55.tar.gz',
#  'pdbnt.52.tar.gz',
#  'cdd_delta.tar.gz.md5',
#  'refseq_genomic.56.tar.gz',
#  'nt.14.tar.gz',
#  'refseq_genomic.62.tar.gz.md5',
#  'refseq_genomic.57.tar.gz',
#  'tsa_nt.03.tar.gz.md5',
#  'refseq_genomic.58.tar.gz',
#  'refseq_genomic.63.tar.gz.md5',
#  'refseq_genomic.59.tar.gz',
#  'refseq_genomic.64.tar.gz.md5',
#  'refseq_genomic.60.tar.gz',
#  'tsa_nt.03.tar.gz',
#  'refseq_protein.07.tar.gz.md5',
#  'other_genomic.109.tar.gz.md5',
#  'human_genomic.11.tar.gz.md5',
#  'human_genomic.11.tar.gz',
#  'est_others.10.tar.gz',
#  'est_others.10.tar.gz.md5',
#  'human_genomic.12.tar.gz.md5',
#  'other_genomic.38.tar.gz.md5',
#  'other_genomic.110.tar.gz',
#  'other_genomic.110.tar.gz.md5',
#  'nr.79.tar.gz',
#  'other_genomic.111.tar.gz',
#  'nr.79.tar.gz.md5',
#  'other_genomic.111.tar.gz.md5',
#  'env_nt.29.tar.gz',
#  'other_genomic.112.tar.gz',
#  'nr.80.tar.gz',
#  'other_genomic.112.tar.gz.md5',
#  'nr.80.tar.gz.md5',
#  'other_genomic.113.tar.gz',
#  'nr.81.tar.gz',
#  'other_genomic.113.tar.gz.md5',
#  'nr.81.tar.gz.md5',
#  'other_genomic.114.tar.gz',
#  'nr.82.tar.gz',
#  'other_genomic.114.tar.gz.md5',
#  'nr.82.tar.gz.md5',
#  'other_genomic.115.tar.gz',
#  'pdbnt.53.tar.gz',
#  'other_genomic.115.tar.gz.md5',
#  'pdbnt.54.tar.gz',
#  'other_genomic.116.tar.gz',
#  'nt.53.tar.gz',
#  'other_genomic.116.tar.gz.md5',
#  'nt.53.tar.gz.md5',
#  'other_genomic.117.tar.gz',
#  'other_genomic.38.tar.gz',
#  'other_genomic.39.tar.gz.md5',
#  'nt.54.tar.gz',
#  'other_genomic.117.tar.gz.md5',
#  'other_genomic.39.tar.gz',
#  'other_genomic.40.tar.gz.md5',
#  'nt.54.tar.gz.md5',
#  'other_genomic.118.tar.gz',
#  'other_genomic.40.tar.gz',
#  'other_genomic.41.tar.gz.md5',
#  'env_nt.30.tar.gz',
#  'other_genomic.118.tar.gz.md5',
#  'other_genomic.41.tar.gz',
#  'other_genomic.42.tar.gz.md5',
#  'nr.83.tar.gz.md5',
#  'other_genomic.119.tar.gz',
#  'other_genomic.42.tar.gz',
#  'other_genomic.43.tar.gz.md5',
#  'env_nt.31.tar.gz',
#  'other_genomic.119.tar.gz.md5',
#  'other_genomic.43.tar.gz',
#  'other_genomic.44.tar.gz.md5',
#  'other_genomic.44.tar.gz',
#  'other_genomic.45.tar.gz.md5',
#  'nt.55.tar.gz',
#  'other_genomic.120.tar.gz',
#  'other_genomic.45.tar.gz',
#  'nt.55.tar.gz.md5',
#  'other_genomic.120.tar.gz.md5',
#  'pdbnt.55.tar.gz',
#  'other_genomic.121.tar.gz',
#  'other_genomic.121.tar.gz.md5',
#  'nr.84.tar.gz',
#  'other_genomic.122.tar.gz',
#  'nr.84.tar.gz.md5',
#  'other_genomic.122.tar.gz.md5',
#  'nt.56.tar.gz',
#  'other_genomic.123.tar.gz',
#  'nt.56.tar.gz.md5',
#  'other_genomic.123.tar.gz.md5',
#  'pdbnt.56.tar.gz',
#  'other_genomic.124.tar.gz',
#  'nt.57.tar.gz',
#  'nt.15.tar.gz.md5',
#  'human_genomic.12.tar.gz',
#  'nr.11.tar.gz',
#  'nt.57.tar.gz.md5',
#  'nr.12.tar.gz.md5',
#  'other_genomic.124.tar.gz.md5',
#  'other_genomic.125.tar.gz',
#  'refseq_genomic.61.tar.gz',
#  'other_genomic.125.tar.gz.md5',
#  'refseq_genomic.62.tar.gz',
#  'refseq_genomic.65.tar.gz.md5',
#  'refseq_genomic.63.tar.gz',
#  'refseq_genomic.66.tar.gz.md5',
#  'refseq_protein.07.tar.gz',
#  'tsa_nt.04.tar.gz.md5',
#  'nr.12.tar.gz',
#  'nt.15.tar.gz',
#  'pdbnt.57.tar.gz',
#  'ref_prok_rep_genomes.05.tar.gz.md5',
#  'refseq_protein.08.tar.gz.md5',
#  'other_genomic.126.tar.gz',
#  'refseq_genomic.64.tar.gz',
#  'other_genomic.126.tar.gz.md5',
#  'refseq_protein.08.tar.gz',
#  'tsa_nt.04.tar.gz',
#  'nr.13.tar.gz.md5',
#  'nt.16.tar.gz.md5',
#  'refseq_rna.02.tar.gz.md5',
#  'ref_viruses_rep_genomes.tar.gz.md5',
#  'refseq_genomic.67.tar.gz.md5',
#  'ref_viroids_rep_genomes.tar.gz.md5',
#  'refseq_genomic.65.tar.gz',
#  'other_genomic.127.tar.gz',
#  'refseq_genomic.66.tar.gz',
#  'refseq_genomic.68.tar.gz.md5',
#  'other_genomic.127.tar.gz.md5',
#  'other_genomic.46.tar.gz.md5',
#  'refseq_genomic.69.tar.gz.md5',
#  'other_genomic.47.tar.gz.md5',
#  'refseq_genomic.68.tar.gz',
#  'refseq_genomic.67.tar.gz',
#  'other_genomic.128.tar.gz',
#  'refseq_genomic.70.tar.gz.md5',
#  'other_genomic.48.tar.gz.md5',
#  'refseq_genomic.69.tar.gz',
#  'other_genomic.128.tar.gz.md5',
#  'refseq_rna.02.tar.gz',
#  'other_genomic.129.tar.gz',
#  'other_genomic.129.tar.gz.md5',
#  'nr.13.tar.gz',
#  'other_genomic.130.tar.gz',
#  'refseq_genomic.70.tar.gz',
#  'other_genomic.46.tar.gz',
#  'other_genomic.49.tar.gz.md5',
#  'other_genomic.47.tar.gz',
#  'other_genomic.50.tar.gz.md5',
#  'other_genomic.48.tar.gz',
#  'refseq_genomic.71.tar.gz.md5',
#  'other_genomic.49.tar.gz',
#  'nr.14.tar.gz.md5',
#  'refseq_genomic.72.tar.gz.md5',
#  'other_genomic.130.tar.gz.md5',
#  'other_genomic.50.tar.gz',
#  'nt.16.tar.gz',
#  'other_genomic.131.tar.gz',
#  'other_genomic.131.tar.gz.md5',
#  'refseq_genomic.73.tar.gz.md5',
#  'other_genomic.132.tar.gz',
#  'refseq_genomic.74.tar.gz.md5',
#  'refseq_genomic.71.tar.gz',
#  'refseq_genomic.72.tar.gz',
#  'other_genomic.51.tar.gz.md5',
#  'refseq_genomic.73.tar.gz',
#  'refseq_genomic.75.tar.gz.md5',
#  'other_genomic.51.tar.gz',
#  'refseq_genomic.74.tar.gz',
#  'refseq_protein.09.tar.gz.md5',
#  'refseq_genomic.75.tar.gz',
#  'other_genomic.52.tar.gz.md5',
#  'refseq_protein.09.tar.gz',
#  'tsa_nt.05.tar.gz.md5',
#  'refseq_genomic.76.tar.gz.md5',
#  'refseq_genomic.76.tar.gz',
#  'refseq_genomic.77.tar.gz.md5',
#  'other_genomic.52.tar.gz',
#  'other_genomic.53.tar.gz.md5',
#  'refseq_genomic.77.tar.gz',
#  'other_genomic.132.tar.gz.md5',
#  'tsa_nt.05.tar.gz',
#  'refseq_genomic.78.tar.gz.md5',
#  'refseq_genomic.78.tar.gz',
#  'refseq_genomic.79.tar.gz.md5',
#  'refseq_genomic.79.tar.gz',
#  'cloud',
#  'refseq_genomic.80.tar.gz.md5',
#  'nr.14.tar.gz',
#  'refseq_genomic.80.tar.gz',
#  'nr.16.tar.gz.md5',
#  'other_genomic.53.tar.gz',
#  'refseq_genomic.81.tar.gz.md5',
#  'refseq_genomic.81.tar.gz',
#  'refseq_genomic.82.tar.gz.md5',
#  'refseq_genomic.82.tar.gz',
#  'htgs.10.tar.gz',
#  'htgs.10.tar.gz.md5',
#  'other_genomic.19.tar.gz.md5',
#  'nr.15.tar.gz.md5',
#  'other_genomic.133.tar.gz',
#  'other_genomic.133.tar.gz.md5',
#  'other_genomic.134.tar.gz',
#  'other_genomic.134.tar.gz.md5',
#  'other_genomic.135.tar.gz',
#  'other_genomic.135.tar.gz.md5',
#  'other_genomic.136.tar.gz',
#  'other_genomic.136.tar.gz.md5',
#  'other_genomic.137.tar.gz',
#  'tsa_nt.00.tar.gz.md5',
#  'refseq_genomic.83.tar.gz.md5',
#  'refseq_genomic.83.tar.gz',
#  'gss_annot.00.tar.gz',
#  'gss_annot.00.tar.gz.md5',
#  'other_genomic.54.tar.gz',
#  'other_genomic.54.tar.gz.md5',
#  'other_genomic.55.tar.gz',
#  'other_genomic.55.tar.gz.md5',
#  'other_genomic.56.tar.gz',
#  'other_genomic.56.tar.gz.md5',
#  'nr.30.tar.gz.md5',
#  'refseq_genomic.151.tar.gz',
#  'refseq_genomic.151.tar.gz.md5',
#  'refseq_genomic.152.tar.gz',
#  'refseq_genomic.152.tar.gz.md5',
#  'other_genomic.75.tar.gz',
#  'other_genomic.75.tar.gz.md5',
#  'refseq_genomic.140.tar.gz',
#  'refseq_genomic.140.tar.gz.md5',
#  'other_genomic.76.tar.gz',
#  'other_genomic.76.tar.gz.md5',
#  'refseq_protein.14.tar.gz',
#  'refseq_protein.14.tar.gz.md5',
#  'other_genomic.77.tar.gz',
#  'other_genomic.77.tar.gz.md5',
#  'refseq_genomic.141.tar.gz',
#  'refseq_genomic.141.tar.gz.md5',
#  'refseq_genomic.142.tar.gz',
#  'refseq_genomic.142.tar.gz.md5',
#  'other_genomic.78.tar.gz',
#  'other_genomic.78.tar.gz.md5',
#  'refseq_genomic.143.tar.gz',
#  'refseq_genomic.143.tar.gz.md5',
#  'refseq_genomic.144.tar.gz',
#  'refseq_genomic.144.tar.gz.md5',
#  'refseq_genomic.145.tar.gz',
#  'refseq_genomic.145.tar.gz.md5',
#  'refseq_genomic.146.tar.gz',
#  'refseq_genomic.146.tar.gz.md5',
#  'refseq_genomic.147.tar.gz',
#  'nt.26.tar.gz',
#  'refseq_genomic.147.tar.gz.md5',
#  'nt.26.tar.gz.md5',
#  'refseq_genomic.148.tar.gz',
#  'pdbnt.26.tar.gz',
#  'refseq_genomic.148.tar.gz.md5',
#  'nr.28.tar.gz',
#  'refseq_rna.05.tar.gz',
#  'nr.28.tar.gz.md5',
#  'refseq_rna.05.tar.gz.md5',
#  'swissprot.tar.gz',
#  'pdbnt.26.tar.gz.md5',
#  'nr.29.tar.gz',
#  'refseq_protein.15.tar.gz',
#  'nr.29.tar.gz.md5',
#  'refseq_protein.15.tar.gz.md5',
#  'pdbnt.27.tar.gz',
#  'refseq_genomic.149.tar.gz',
#  'nt.27.tar.gz',
#  'refseq_genomic.149.tar.gz.md5',
#  'nt.27.tar.gz.md5',
#  'refseq_protein.16.tar.gz',
#  'nr.31.tar.gz',
#  'refseq_protein.16.tar.gz.md5',
#  'nr.31.tar.gz.md5',
#  'swissprot.tar.gz.md5',
#  'env_nt.04.tar.gz',
#  'refseq_genomic.150.tar.gz',
#  'env_nt.05.tar.gz',
#  'refseq_genomic.150.tar.gz.md5',
#  'env_nt.06.tar.gz',
#  'refseq_genomic.153.tar.gz',
#  'pdbnt.00.tar.gz.md5',
#  'pdbnt.01.tar.gz',
#  'pdbnt.01.tar.gz.md5',
#  'pdbnt.02.tar.gz',
#  'pdbnt.02.tar.gz.md5',
#  'pdbnt.03.tar.gz',
#  'pdbnt.03.tar.gz.md5',
#  'pdbnt.04.tar.gz',
#  'pdbnt.04.tar.gz.md5',
#  'pdbnt.05.tar.gz',
#  'pdbnt.05.tar.gz.md5',
#  'pdbnt.06.tar.gz',
#  'pdbnt.06.tar.gz.md5',
#  'pdbnt.07.tar.gz',
#  'pdbnt.07.tar.gz.md5',
#  'pdbnt.08.tar.gz',
#  'pdbnt.08.tar.gz.md5',
#  'pdbnt.09.tar.gz',
#  'pdbnt.09.tar.gz.md5',
#  'pdbnt.10.tar.gz',
#  'pdbnt.10.tar.gz.md5',
#  'pdbnt.11.tar.gz',
#  'pdbnt.11.tar.gz.md5',
#  'pdbnt.12.tar.gz',
#  'pdbnt.12.tar.gz.md5',
#  'pdbnt.13.tar.gz',
#  'pdbnt.13.tar.gz.md5',
#  'pdbnt.14.tar.gz',
#  'pdbnt.14.tar.gz.md5',
#  'pdbnt.15.tar.gz',
#  'pdbnt.15.tar.gz.md5',
#  'pdbnt.16.tar.gz',
#  'pdbnt.16.tar.gz.md5',
#  'refseq_genomic.153.tar.gz.md5',
#  'pdbnt.27.tar.gz.md5',
#  'refseq_genomic.154.tar.gz',
#  'pdbnt.17.tar.gz',
#  'pdbnt.17.tar.gz.md5',
#  'nt.17.tar.gz',
#  'nt.17.tar.gz.md5',
#  'tsa_nt.06.tar.gz',
#  'tsa_nt.06.tar.gz.md5',
#  'other_genomic.137.tar.gz.md5',
#  'other_genomic.138.tar.gz',
#  'other_genomic.138.tar.gz.md5',
#  'other_genomic.139.tar.gz',
#  'other_genomic.139.tar.gz.md5',
#  'other_genomic.140.tar.gz',
#  'other_genomic.140.tar.gz.md5',
#  'other_genomic.141.tar.gz',
#  'other_genomic.141.tar.gz.md5',
#  'other_genomic.142.tar.gz',
#  'other_genomic.142.tar.gz.md5',
#  'other_genomic.143.tar.gz',
#  'other_genomic.143.tar.gz.md5',
#  'other_genomic.144.tar.gz',
#  'other_genomic.144.tar.gz.md5',
#  'other_genomic.145.tar.gz',
#  'other_genomic.145.tar.gz.md5',
#  'pdbnt.18.tar.gz',
#  'pdbnt.18.tar.gz.md5',
#  'nt.18.tar.gz',
#  'nt.18.tar.gz.md5',
#  'other_genomic.146.tar.gz',
#  'other_genomic.146.tar.gz.md5',
#  'other_genomic.147.tar.gz',
#  'other_genomic.147.tar.gz.md5',
#  'refseq_protein.10.tar.gz',
#  'refseq_protein.10.tar.gz.md5',
#  'refseq_protein.11.tar.gz',
#  'refseq_protein.11.tar.gz.md5',
#  'env_nt.07.tar.gz',
#  'refseq_genomic.154.tar.gz.md5',
#  'env_nt.08.tar.gz',
#  'refseq_protein.17.tar.gz',
#  'env_nt.09.tar.gz',
#  'refseq_protein.17.tar.gz.md5',
#  'env_nt.10.tar.gz',
#  'env_nt.04.tar.gz.md5',
#  'nt.28.tar.gz',
#  'env_nt.05.tar.gz.md5',
#  'nt.28.tar.gz.md5',
#  'env_nt.06.tar.gz.md5',
#  'nr.17.tar.gz',
#  'nr.17.tar.gz.md5',
#  'nr.18.tar.gz',
#  'nr.18.tar.gz.md5',
#  'nr.19.tar.gz',
#  'nr.19.tar.gz.md5',
#  'nr.20.tar.gz',
#  'nr.20.tar.gz.md5',
#  'nr.21.tar.gz',
#  'nr.21.tar.gz.md5',
#  'nr.22.tar.gz',
#  'nr.22.tar.gz.md5',
#  'env_nt.07.tar.gz.md5',
#  'env_nt.08.tar.gz.md5',
#  'env_nt.09.tar.gz.md5',
#  'env_nt.10.tar.gz.md5',
#  'pdbnt.28.tar.gz',
#  'pdbnt.28.tar.gz.md5',
#  'refseq_genomic.155.tar.gz',
#  'refseq_genomic.155.tar.gz.md5',
#  'refseq_genomic.156.tar.gz',
#  'refseq_genomic.156.tar.gz.md5',
#  'refseq_genomic.157.tar.gz',
#  'refseq_genomic.157.tar.gz.md5',
#  'refseq_rna.03.tar.gz',
#  'refseq_rna.03.tar.gz.md5',
#  'nr.23.tar.gz',
#  'nr.23.tar.gz.md5',
#  'refseq_genomic.158.tar.gz',
#  'nr.32.tar.gz',
#  'refseq_genomic.158.tar.gz.md5',
#  'refseq_protein.12.tar.gz',
#  'nr.32.tar.gz.md5',
#  'refseq_protein.12.tar.gz.md5',
#  'nr.24.tar.gz',
#  ...]

# %% [markdown]
# ### Read ftp file into memory

# %%
import ftplib

ftp = ftplib.FTP('ftp.ncbi.nlm.nih.gov')
ftp.login(user='anonymous', passwd='anonymous')
ftp.cwd('blast/db/')

# Just to check the connection. Does nothing
ftp.voidcmd('NOOP')

data = []

ftp.retrbinary('RETR nr.00.tar.gz.md5', data.append)

    
ftp.quit()
data
# Out:
# [b'4f5b6e7d134ccd3e3645c5675cd3e9a3  nr.00.tar.gz\n']

# %% [markdown]
# ## Download a large file
#
# Helpful post:
# https://stackoverflow.com/questions/8323607/download-big-files-via-ftp-with-python

# %% [markdown]
# #### Connect

# %% [markdown]
# #### Download
#
# Downloading one __nt.03.tar.gz__ file in 6*1024 chunks:
# CPU times: user 1.2 s, sys: 1.99 s, total: 3.19 s
# Wall time: 3min 8s
#
# Same, but with no chunks:
# CPU times: user 1.02 s, sys: 1.71 s, total: 2.73 s
# Wall time: 2min 15s

# %%
# %%time

import ftplib
def ncbi_connect():
    try:
        ftp = ftplib.FTP('ftp.ncbi.nlm.nih.gov')
        ftp.login(user='anonymous', passwd='anonymous')
        ftp.cwd('blast/db/')
    except IOError as e:
        print('Error connecting to ftp: {}'.format(e))
    except ftplib.error_perm as e:
        print("FTP error. {}".format(e))
        ftp.quit()
        
    return ftp


#file_name = 'nt.03.tar.gz'  # 3 mins
file_name = 'nr.35.tar.gz'  # 12 sec

max_download_attempts = 3
ftp = ncbi_connect()
ftp_file_size = ftp.size(file_name)
with open('out/'+file_name, 'wb') as f:
    while ftp_file_size != f.tell():
        try:
            print('Original ftp file size:     {}'.format(ftp.size(file_name)))
            if f.tell() != 0:
                ftp.retrbinary('RETR {}'.format(file_name), f.write, f.tell())
            else:    
                ftp.retrbinary('RETR {}'.format(file_name), f.write)
            print('Downloaded local file size: {}'.format(f.tell()))
        except (ftplib.error_temp, IOError) as e:
            print('Problems with ftp connection. Error: {}'.format(e))
            if max_download_attempts != 0:
                print('Re-trying the download of file: {}'.format(file_name))
                ftp = ncbi_connect()
                max_download_attempts -= 1
            else:
                print('Failed to download file: {}'.format(file_name))
                break
        except:
            print('Something went wrong with the download of file: {} Re-download will not be attempted.'.format(file_name))

ftp.quit()
# Out:
# Original ftp file size:     119934159
# Downloaded local file size: 119934159
# CPU times: user 86.3 ms, sys: 187 ms, total: 274 ms
# Wall time: 6.81 s
